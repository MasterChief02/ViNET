# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from model_training import Dataset

# %%
AIRTEL = "ISP 1"
JIO = "ISP 2"
VI = "ISP 3"

# %% [markdown]
# # ROC AUC

# %%
summ_curve_jio = np.loadtxt('numbers/Jio_ViLTE_vs_ViNET_roc_curve.txt', delimiter=',')
pl_curve_jio = np.loadtxt('numbers/Jio_ViLTE_vs_ViNET_pl_roc_curve.txt', delimiter=',')

with open("numbers/Jio_ViLTE_vs_ViNET_auc.txt") as f:
    lines = f.readlines()
    summ_auc_jio = float(lines[0].strip())
    chunk_summ_auc_jio = float(lines[1].strip())

with open("numbers/Jio_ViLTE_vs_ViNET_pl_auc.txt") as f:
    lines = f.readlines()
    pl_auc_jio = float(lines[0].strip())
    chunk_pl_auc_jio = float(lines[1].strip())
    

summ_curve_airtel = np.loadtxt('numbers/Airtel_ViLTE_vs_ViNET_roc_curve.txt', delimiter=',')
pl_curve_airtel = np.loadtxt('numbers/Airtel_ViLTE_vs_ViNET_pl_roc_curve.txt', delimiter=',')

with open("numbers/Airtel_ViLTE_vs_ViNET_auc.txt") as f:
    lines = f.readlines()
    summ_auc_airtel = float(lines[0].strip())
    chunk_summ_auc_airtel = float(lines[1].strip())
with open("numbers/Airtel_ViLTE_vs_ViNET_pl_auc.txt") as f:
    lines = f.readlines()
    pl_auc_airtel = float(lines[0].strip())
    chunk_pl_auc_airtel = float(lines[1].strip())
    
summ_curve_vi = np.loadtxt('numbers/VI_ViLTE_vs_VInet_roc_curve.txt', delimiter=',')
pl_curve_vi = np.loadtxt('numbers/VI_ViLTE_vs_VInet_pl_roc_curve.txt', delimiter=',')

with open("numbers/VI_ViLTE_vs_VInet_auc.txt") as f:
    lines = f.readlines()
    summ_auc_vi = float(lines[0].strip())
    chunk_summ_auc_vi = float(lines[1].strip())
with open("numbers/VI_ViLTE_vs_VInet_pl_auc.txt") as f:
    lines = f.readlines()
    pl_auc_vi = float(lines[0].strip())
    chunk_pl_auc_vi = float(lines[1].strip())

# %%
# print(summ_curve.shape)
# print(pl_curve.shape)

# # get the first column

# %%
pallete = sns.color_palette("rocket")
pallete = [pallete[2], pallete[3], pallete[5]]

# %%
fig, axs = plt.subplots(1, 3, figsize=(11, 3.5))

axs[0].plot(summ_curve_airtel[:, 0], summ_curve_airtel[:, 1], label=f'Sum Stats AUC: {summ_auc_airtel:.2f}', lw=2, color=pallete[0])
axs[0].plot(pl_curve_airtel[:, 0], pl_curve_airtel[:, 1], label=f'Quant PLs AUC: {pl_auc_airtel:.2f}', lw=2, color=pallete[0], linestyle='-.')
axs[0].plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
axs[0].set_title(AIRTEL, fontsize=12)
axs[0].grid(axis='y')
axs[0].set_xlim(0, 1)
axs[0].set_ylim(0, 1)
axs[0].spines["top"].set_visible(False)
axs[0].spines["right"].set_visible(False)
axs[0].legend(fontsize='small')
# axs[0].set_ylabel('True Positive Rate', fontsize=12)
# axs[0].set_xlabel('False Positive Rate', fontsize=12)


axs[1].plot(summ_curve_jio[:, 0], summ_curve_jio[:, 1], label=f'Sum Stats AUC: {summ_auc_jio:.2f}', lw=2, color=pallete[1])
axs[1].plot(pl_curve_jio[:, 0], pl_curve_jio[:, 1], label=f'Quant PLs AUC: {pl_auc_jio:.2f}', lw=2, color=pallete[1], linestyle='-.')    
axs[1].plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
axs[1].set_title(JIO, fontsize=12)
axs[1].grid(axis='y')
axs[1].set_xlim(0, 1)
axs[1].set_ylim(0, 1)
axs[1].spines["top"].set_visible(False)
axs[1].spines["right"].set_visible(False)
axs[1].legend(fontsize='small')
# axs[1].set_ylabel('True Positive Rate', fontsize=12)
# axs[1].set_xlabel('False Positive Rate', fontsize=12)

axs[2].plot(summ_curve_vi[:, 0], summ_curve_vi[:, 1], label=f'Sum Stats AUC: {summ_auc_vi:.2f}', lw=2, color=pallete[2])
axs[2].plot(pl_curve_vi[:, 0], pl_curve_vi[:, 1], label=f'Quant PLs AUC: {pl_auc_vi:.2f}', lw=2, color=pallete[2], linestyle='-.')    
axs[2].plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
axs[2].set_title(VI, fontsize=12)
axs[2].grid(axis='y')
axs[2].set_xlim(0, 1)
axs[2].set_ylim(0, 1)
axs[2].spines["top"].set_visible(False)
axs[2].spines["right"].set_visible(False)
axs[2].legend(fontsize='small')
# axs[2].set_ylabel('True Positive Rate', fontsize=12)
# axs[2].set_xlabel('False Positive Rate', fontsize=12)

fig.text(0.5, 0.04, 'False Positive Rate', ha='center', va='center', fontsize=12)
fig.text(0.04, 0.5, 'True Positive Rate', ha='center', va='center', rotation='vertical', fontsize=12)

plt.tight_layout(rect=[0.05, 0.05, 1, 1])
# plt.xlabel('False Positive Rate', fontsize=12)
# plt.ylabel('True Positive Rate', fontsize=12)
plt.savefig(f"paper_figures/ViLTE_vs_ViNET_roc_curve.pdf", bbox_inches='tight')
plt.show()

# %%
# plt.figure(figsize=(5, 3))
# plt.plot(summ_curve_jio[:, 0], summ_curve_jio[:, 1], label=f'Jio Summary Stats AUC: {summ_auc_jio:.2f}', lw=2, color='tab:orange')
# plt.plot(pl_curve_jio[:, 0], pl_curve_jio[:, 1], label=f'Jio pl Stats AUC: {pl_auc_jio:.2f}', lw=2, color='tab:blue')
# plt.plot(summ_curve_airtel[:, 0], summ_curve_airtel[:, 1], label=f'Airtel Summary Stats AUC: {summ_auc_airtel:.2f}', lw=2, color='tab:orange', linestyle='-.')
# plt.plot(pl_curve_airtel[:, 0], pl_curve_airtel[:, 1], label=f'Airtel pl Stats AUC: {pl_auc_airtel:.2f}', lw=2, color='tab:blue', linestyle='-.')

# plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title(f"ROC AUC for ViLTE vs ViNET")
# plt.legend()
# plt.grid(True)
# plt.savefig(f"paper_figures/Jio_ViLTE_vs_ViNET_roc_curve.pdf", bbox_inches='tight')

# %%
summ_curve_jio_one_transfer = np.loadtxt('numbers/Jio_ViLTE_vs_ViNET_one_transfer_roc_curve.txt', delimiter=',')
pl_curve_jio_one_transfer = np.loadtxt('numbers/Jio_ViLTE_vs_ViNET_pl_one_transfer_roc_curve.txt', delimiter=',')
with open("numbers/Jio_ViLTE_vs_ViNET_one_transfer_auc.txt") as f:
    lines = f.readlines()
    summ_auc_jio_one_transfer = float(lines[0].strip())
    chunk_summ_auc_jio_one_transfer = float(lines[1].strip())

with open("numbers/Jio_ViLTE_vs_ViNET_pl_one_transfer_auc.txt") as f:
    lines = f.readlines()
    pl_auc_jio_one_transfer = float(lines[0].strip())
    chunk_pl_auc_jio_one_transfer = float(lines[1].strip())

# %%
# plt.figure(figsize=(4, 3.5))
# plt.plot(summ_curve_jio[:, 0], summ_curve_jio[:, 1], label=f'Sum Stats Before\nAUC: {summ_auc_jio:.2f}', lw=2, color='tab:blue')
# # plt.plot(pl_curve_jio[:, 0], pl_curve_jio[:, 1], label=f'Jio pl Stats AUC: {pl_auc_jio:.2f}', lw=2, color='tab:blue')
# plt.plot(summ_curve_jio_one_transfer[:, 0], summ_curve_jio_one_transfer[:, 1], label=f'Sum Stats After\nAUC: {summ_auc_jio_one_transfer:.2f}', lw=2, color='tab:blue', linestyle='-.')
# # plt.plot(pl_curve_jio_one_transfer[:, 0], pl_curve_jio_one_transfer[:, 1], label=f'Jio One Transfer pl Stats AUC: {pl_auc_jio_one_transfer:.2f}', lw=2, color='tab:blue', linestyle='-.')

# plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# # plt.title(f"ROC AUC for ViLTE vs ViNET")
# plt.legend()
# plt.grid(True)
# plt.savefig(f"paper_figures/Jio_ViLTE_vs_ViNET_one_transfer_roc_curve.pdf", bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3.5))

axs[0].plot(summ_curve_jio[:, 0], summ_curve_jio[:, 1], label=f'Before AUC: {summ_auc_jio:.2f}', lw=2, color=pallete[1])
axs[0].plot(summ_curve_jio_one_transfer[:, 0], summ_curve_jio_one_transfer[:, 1], label=f'After AUC: {summ_auc_jio_one_transfer:.2f}', lw=2, color=pallete[1], linestyle='-.')
axs[0].plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
axs[0].set_title('Summary Statistics', fontsize=12)
axs[0].grid(axis='y')
axs[0].set_xlim(0, 1)
axs[0].set_ylim(0, 1)
axs[0].legend()
axs[0].spines["top"].set_visible(False)
axs[0].spines["right"].set_visible(False)
axs[0].legend(fontsize='small')
axs[0].set_ylabel('True Positive Rate', fontsize=12)
axs[0].set_xlabel('False Positive Rate', fontsize=12)


axs[1].plot(pl_curve_jio[:, 0], pl_curve_jio[:, 1], label=f'Before AUC: {pl_auc_jio:.2f}', lw=2, color=pallete[1])    
axs[1].plot(pl_curve_jio_one_transfer[:, 0], pl_curve_jio_one_transfer[:, 1], label=f'After AUC: {pl_auc_jio_one_transfer:.2f}', lw=2, color=pallete[1], linestyle='-.')
axs[1].plot([0, 1], [0, 1], linestyle='--', lw=2, color='gray', label='Chance', alpha=.8)
axs[1].set_title('Quantized PLs', fontsize=12)
axs[1].grid(axis='y')
axs[1].set_xlim(0, 1)
axs[1].set_ylim(0, 1)
axs[1].spines["top"].set_visible(False)
axs[1].spines["right"].set_visible(False)
axs[1].legend(fontsize='small', loc='lower right')
axs[1].set_ylabel('True Positive Rate', fontsize=12)
axs[1].set_xlabel('False Positive Rate', fontsize=12)

plt.tight_layout()
plt.savefig(f"paper_figures/Jio_ViLTE_vs_ViNET_one_transfer_roc_curve.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Byte Distribution data

# %%
airtel_vilte = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_airtel_vilte__byte_count.txt', delimiter=',')
airtel_vinet = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_airtel_vinet__byte_count.txt', delimiter=',')
jio_vilte = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_jio_vilte__byte_count.txt', delimiter=',')
jio_vinet = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_jio_vinet_byte_count.txt', delimiter=',')
vi_vilte = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_vi_vilte__byte_count.txt', delimiter=',')
vi_vinet = np.loadtxt('/home/vinet/sec_analysis/ml_pipeline/numbers/_home_vinet_sec_analysis_forbidden_bit_60s_vi_vinet__byte_count.txt', delimiter=',')

# %%
# # make a 2 x 2 plot, with airtel and jio as rows, and vilte and vinet as columns
# fig, axs = plt.subplots(2, 2, figsize=(7,5))

# fig.subplots_adjust(wspace=0.2, hspace=0.3)

# axs[0, 0].bar(range(256), airtel_vilte, alpha=0.7, edgecolor=None, linewidth=0, width=1)
# axs[0, 0].set_title('ViLTE')
# axs[0, 0].set_ylim(0, 2)
# axs[0, 0].set_xlim(0, 255)
# axs[0, 0].set_ylabel('Airtel')
# axs[0, 0].grid(True)
# # axs[0, 0].set_xlabel('Byte Value')

# axs[0, 1].bar(range(256), airtel_vinet, color="tab:orange", alpha=0.7, edgecolor=None, linewidth=0, width=1)
# axs[0, 1].set_title('ViNET')
# axs[0, 1].set_ylim(0, 2)
# axs[0, 1].set_xlim(0, 255)
# axs[0, 1].grid(True)


# axs[1, 0].bar(range(256), jio_vilte, alpha=0.7, edgecolor=None, linewidth=0, width=1)
# axs[1, 0].set_ylabel('Jio')
# axs[1, 0].set_ylim(0, 2)
# axs[1, 0].set_xlim(0, 255)
# axs[1, 0].grid(True)

# axs[1, 1].bar(range(256), jio_vinet, color="tab:orange", alpha=0.7, edgecolor=None, linewidth=0, width=1)
# axs[1, 1].set_ylim(0, 2)
# axs[1, 1].set_xlim(0, 255)
# axs[1, 1].grid(True)

# fig.text(0, 0.5, 'Percentage of Total Bytes', va='center', rotation='vertical', fontsize=11)
# fig.text(0.5, 0, 'Byte Values', ha='center', fontsize=11)

# fig.savefig(f"paper_figures/Jio_Airtel_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3))

axs[0].bar(range(256), airtel_vilte, alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[0].set_title('ViLTE', fontsize=12)
axs[0].grid()
axs[0].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[0].set_xlabel('Byte Values', fontsize=12)
axs[0].set_ylim(0, 2)
axs[0].set_xlim(0, 255)


axs[1].bar(range(256), airtel_vinet, color="tab:orange", alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[1].set_title('ViNET', fontsize=12)
axs[1].grid()
axs[1].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[1].set_xlabel('Byte Values', fontsize=12)
axs[1].set_ylim(0, 2)
axs[1].set_xlim(0, 255)

plt.tight_layout()
plt.savefig(f"paper_figures/Airtel_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3))

axs[0].bar(range(256), jio_vilte, alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[0].set_title('ViLTE', fontsize=12)
axs[0].grid()
axs[0].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[0].set_xlabel('Byte Values', fontsize=12)
axs[0].set_ylim(0, 2)
axs[0].set_xlim(0, 255)


axs[1].bar(range(256), jio_vinet, color="tab:orange", alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[1].set_title('ViNET', fontsize=12)
axs[1].grid()
axs[1].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[1].set_xlabel('Byte Values', fontsize=12)
axs[1].set_ylim(0, 2)
axs[1].set_xlim(0, 255)

plt.tight_layout()
plt.savefig(f"paper_figures/Jio_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3))

axs[0].bar(range(256), vi_vilte, alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[0].set_title('ViLTE', fontsize=12)
axs[0].grid()
axs[0].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[0].set_xlabel('Byte Values', fontsize=12)
axs[0].set_ylim(0, 2)
axs[0].set_xlim(0, 255)


axs[1].bar(range(256), vi_vinet, color="tab:orange", alpha=0.7, edgecolor=None, linewidth=0, width=1)
axs[1].set_title('ViNET', fontsize=12)
axs[1].grid()
axs[1].set_ylabel('Percentage of Total Bytes', fontsize=12)
axs[1].set_xlabel('Byte Values', fontsize=12)
axs[1].set_ylim(0, 2)
axs[1].set_xlim(0, 255)

plt.tight_layout()
plt.savefig(f"paper_figures/Jio_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 2, figsize=(7, 6))  # 3 rows (ISPs), 2 cols (ViLTE and ViNET)

# Row 1: Airtel
axs[0, 0].bar(range(256), airtel_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE')
axs[0, 0].set_title(AIRTEL, fontsize=10)
axs[0, 0].grid()
axs[0, 0].set_ylabel('% of Total Bytes')
# axs[0, 0].set_xlabel('Byte Values')
axs[0, 0].set_ylim(0, 2)
axs[0, 0].set_xlim(0, 255)

axs[0, 1].bar(range(256), airtel_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[0, 1].set_title(AIRTEL, fontsize=10)
axs[0, 1].grid()
# axs[0, 1].set_xlabel('Byte Values')
axs[0, 1].set_ylim(0, 2)
axs[0, 1].set_xlim(0, 255)

# Row 2: Jio
axs[1, 0].bar(range(256), jio_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE')
axs[1, 0].set_title(JIO, fontsize=10)
axs[1, 0].grid()
axs[1, 0].set_ylabel('% of Total Bytes')
# axs[1, 0].set_xlabel('Byte Values')
axs[1, 0].set_ylim(0, 2)
axs[1, 0].set_xlim(0, 255)

axs[1, 1].bar(range(256), jio_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[1, 1].set_title(JIO, fontsize=10)
axs[1, 1].grid()
# axs[1, 1].set_xlabel('Byte Values')
axs[1, 1].set_ylim(0, 2)
axs[1, 1].set_xlim(0, 255)

# Row 3: Vi
axs[2, 0].bar(range(256), vi_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE')
axs[2, 0].set_title(VI, fontsize=10)
axs[2, 0].grid()
axs[2, 0].set_ylabel('% of Total Bytes')
axs[2, 0].set_xlabel('Byte Values')
axs[2, 0].set_ylim(0, 2)
axs[2, 0].set_xlim(0, 255)

axs[2, 1].bar(range(256), vi_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[2, 1].set_title(VI, fontsize=10)
axs[2, 1].grid()
axs[2, 1].set_xlabel('Byte Values')
axs[2, 1].set_ylim(0, 2)
axs[2, 1].set_xlim(0, 255)

# fig.text(0.305, 0.95, 'ViLTE', ha='center', va='center', fontsize=12)
# fig.text(0.775, 0.95, 'ViNET', ha='center', va='center', fontsize=12)

plt.tight_layout(rect=[0, 0.03, 1, 0.93])
fig.legend(["ViLTE", "ViNET"], loc="lower center", ncol=2, bbox_to_anchor=(0.5, -0.02))
plt.savefig("paper_figures/All_ISPs_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 3, figsize=(9, 5))  # 2 rows, 3 columns


# Row 1: ViLTE for Airtel, Jio, Vi
axs[0, 0].bar(range(256), airtel_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE', color="tab:blue")
axs[0, 0].set_title(AIRTEL, fontsize=10)
axs[0, 0].grid()
axs[0, 0].set_ylabel('% of Total Bytes')
axs[0, 0].set_ylim(0, 2)
axs[0, 0].set_xlim(0, 255)

axs[0, 1].bar(range(256), jio_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE', color="tab:blue")
axs[0, 1].set_title(JIO, fontsize=10)
axs[0, 1].grid()
axs[0, 1].set_ylim(0, 2)
axs[0, 1].set_xlim(0, 255)

axs[0, 2].bar(range(256), vi_vilte, alpha=0.7, linewidth=0, width=1, label='ViLTE', color="tab:blue")
axs[0, 2].set_title(VI, fontsize=10)
axs[0, 2].grid()
axs[0, 2].set_ylim(0, 2)
axs[0, 2].set_xlim(0, 255)

# Row 2: ViNET for Airtel, Jio, Vi
axs[1, 0].bar(range(256), airtel_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[1, 0].grid()
axs[1, 0].set_ylabel('% of Total Bytes')
axs[1, 0].set_xlabel('Byte Values')
axs[1, 0].set_ylim(0, 2)
axs[1, 0].set_xlim(0, 255)

axs[1, 1].bar(range(256), jio_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[1, 1].grid()
axs[1, 1].set_xlabel('Byte Values')
axs[1, 1].set_ylim(0, 2)
axs[1, 1].set_xlim(0, 255)

axs[1, 2].bar(range(256), vi_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1, label='ViNET')
axs[1, 2].grid()
axs[1, 2].set_xlabel('Byte Values')
axs[1, 2].set_ylim(0, 2)
axs[1, 2].set_xlim(0, 255)

plt.tight_layout(rect=[0, 0.03, 1, 0.93])
fig.legend(["ViLTE", "ViNET"], loc="lower center", ncol=2, bbox_to_anchor=(0.5, -0.05))
plt.savefig("paper_figures/All_ISPs_ViLTE_ViNET_byte_count_2x3.pdf", bbox_inches='tight')
plt.show()

# %%
# import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle



fig, axs = plt.subplots(1, 6, figsize=(15, 2.5))  # 1 row, 6 columns

# Airtel
axs[0].bar(range(256), airtel_vilte, alpha=0.7, linewidth=0, width=1)
axs[0].grid()
axs[0].set_ylabel('% of Total Bytes')
axs[0].set_xlabel('Byte Values')
axs[0].set_ylim(0, 2)
axs[0].set_xticks(range(0, 256, 50))
axs[0].set_xlim(0, 255)

axs[1].bar(range(256), airtel_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1)
axs[1].grid()
axs[1].set_xlabel('Byte Values')
axs[1].set_ylim(0, 2)
axs[1].set_xticks(range(0, 256, 50))
axs[1].set_xlim(0, 255)

# Jio
axs[2].bar(range(256), jio_vilte, alpha=0.7, linewidth=0, width=1)
axs[2].grid()
axs[2].set_xlabel('Byte Values')
axs[2].set_ylim(0, 2)
axs[2].set_xticks(range(0, 256, 50))
axs[2].set_xlim(0, 255)

axs[3].bar(range(256), jio_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1)
axs[3].grid()
axs[3].set_xlabel('Byte Values')
axs[3].set_ylim(0, 2)
axs[3].set_xticks(range(0, 256, 50))
axs[3].set_xlim(0, 255)

# Vi
axs[4].bar(range(256), vi_vilte, alpha=0.7, linewidth=0, width=1)
axs[4].grid()
axs[4].set_xlabel('Byte Values')
axs[4].set_ylim(0, 2)
axs[4].set_xticks(range(0, 256, 50))
axs[4].set_xlim(0, 255)

axs[5].bar(range(256), vi_vinet, color="tab:orange", alpha=0.7, linewidth=0, width=1)
axs[5].grid()
axs[5].set_xlabel('Byte Values')
axs[5].set_ylim(0, 2)
axs[5].set_xticks(range(0, 256, 50))
axs[5].set_xlim(0, 255)

# Add combined titles above each ISP's pair of plots
fig.text(0.19, 0.95, AIRTEL, ha='center', va='center', fontsize=11)
fig.text(0.52, 0.95, JIO, ha='center', va='center', fontsize=11)
fig.text(0.84, 0.95, VI, ha='center', va='center', fontsize=11)
fig.legend(["ViLTE", "ViNET"], loc="lower center", ncol=2, bbox_to_anchor=(0.5, -0.07))


plt.tight_layout(rect=[0, 0.04, 1, 0.93])
plt.savefig("paper_figures/All_ISPs_ViLTE_ViNET_byte_count.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Avg Bytes/Sec

# %%
ROOT_PATH = "/home/vinet/sec_analysis/forbidden_bit_60s/features"

dataset = Dataset(ROOT_PATH)

# %%
df_airtel_vilte = dataset.c60.airtel.vilte
df_airtel_vinet = dataset.c60.airtel.vinet

df_airtel_vilte["throughput"] = df_airtel_vilte["total_bytes"] / 60 * (8 / 1024)
df_airtel_vinet["throughput"] = df_airtel_vinet["total_bytes"] / 60 * (8 / 1024)

df_airtel_vilte["throughput"].describe().round(2)
# Out:
# count    1170.00
# mean      158.94
# std        67.42
# min        55.41
# 25%       128.37
# 50%       161.38
# 75%       174.11
# max       526.26
# Name: throughput, dtype: float64

# %%
df_jio_vilte = dataset.c60.jio.vilte
df_jio_vinet = dataset.c60.jio.vinet

df_jio_vilte["throughput"] = df_jio_vilte["total_bytes"] / 60 * (8 / 1024)
df_jio_vinet["throughput"] = df_jio_vinet["total_bytes"] / 60 * (8 / 1024)

df_jio_vilte["throughput"].describe().round(2)
# Out:
# count    1287.00
# mean      852.06
# std       296.70
# min       226.24
# 25%       718.60
# 50%       879.19
# 75%      1033.53
# max      1490.01
# Name: throughput, dtype: float64

# %%
airtel_file_transfer = pd.read_csv("/home/vinet/ViNET_Testing/new_results/airtel/airtel-file-download.log")
jio_file_transfer = pd.read_csv("/home/vinet/ViNET_Testing/new_results/jio/jio-file-download.log")
vi_file_transfer = pd.read_csv("/home/vinet/ViNET_Testing/new_results/vi/vi-file-download.log")

# %%
airtel_file_transfer.columns
# Out:
# Index(['file size(bytes)', ' time taken(s)', ' speed(bytes/s)'], dtype='object')
