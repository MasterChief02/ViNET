# %%
import pandas as pd

data_airtel = pd.read_csv('new_logs/airtel-google-search.log')
data_jio = pd.read_csv('new_logs/jio-gsearch.log')

# %%
data_airtel.columns, data_jio.columns
# Out:
# (Index(['time_taken'], dtype='object'), Index(['time_taken'], dtype='object'))

# %%
data_airtel.describe(), data_jio.describe()
# Out:
# (       time_taken
#  count   10.000000
#  mean     6.990061
#  std      2.698789
#  min      4.809744
#  25%      5.145407
#  50%      5.863146
#  75%      7.547699
#  max     12.826123,
#         time_taken
#  count   10.000000
#  mean     2.921646
#  std      1.240199
#  min      2.156894
#  25%      2.353886
#  50%      2.498401
#  75%      2.819085
#  max      6.361450)

# %%
import matplotlib.pyplot as plt

plt.plot(data_airtel['time_taken'], label='Airtel')
plt.plot(data_jio['time_taken'], label='Jio')
plt.title('Airtel Google Search Time Taken')
plt.xlabel('Time Taken (ms)')
plt.show()
